# %% [markdown]
# # TimeSformer Finetuning Pipeline
#
# Pipeline to train the TimeSformer model using the `cineca` branch and the Hugging Face dataset.

# %% [markdown]
# ## 1. Mount Google Drive
# Mount Drive to store checkpoints and logs persistently.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## 2. Clone Repository

# %%
# !git clone -b cineca https://github.com/AnnikaUnmuessig/Driving_Distraction_Detection.git
# %cd Driving_Distraction_Detection

# %% [markdown]
# ## 3. Install Dependencies

# %%
# !pip install -r requirements.txt
# !pip install accelerate -U

# %% [markdown]
# ## 4. Hugging Face Login
# Required to download the dataset. Provide your Hugging Face access token when prompted.

# %%
from huggingface_hub import notebook_login
notebook_login()

# %% [markdown]
# ## 5. Download Assets
# Download the TimeSformer weights and the dataset to the local Colab storage.

# %%
# !python download_assets.py --output_dir /content/hf_cache

# %% [markdown]
# ## 6. Start Training
# Set paths and run the finetuning script. Outputs are saved directly to Google Drive.

# %%
import os

os.environ["MODEL_PATH"] = "/content/hf_cache/timesformer-hr"
os.environ["DATASET_PATH"] = "/content/hf_cache/distraction_dataset"
os.environ["OUTPUT_DIR"] = "/content/drive/MyDrive/Driving_Distraction_Outputs"

os.makedirs(os.environ["OUTPUT_DIR"], exist_ok=True)

# !python Finetuning.py
